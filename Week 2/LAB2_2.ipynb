# %% [markdown]
# ### Lab 2.2
# ธนธรณ์ ผาลัง 683380576-2

# %%
age = int(input("Please insert your age: "))

if age >= 0 and age < 5:
  print("Yor're too young for movies! Enjoy cartoons.")
elif age >= 5 and age < 13:
  print("G-rated or PG-rated movies.")
elif age >= 13 and age < 18:
  print("PG-13 or R-rated (with parental guidance).")
else:
  yn = input("Do you like action movies? (yes/no)")
  if yn == "yes" or yn == "Yes":
    print("You might enjoy the latest action blockbuster!")
  else:
    print("Any movie rating.")
