# %% [markdown]
# ### Activity 2
# ธนธรณ์ ผาลัง 683380576-2

# %% [markdown]
# ### Activity 2.1
#
# บล็อค A
# 1. กำหนด temp = 25 และให้ is_raining เป็น True
# 2. ใช้คำสั่ง if เพื่อตรวจสอบ<br>
# 2.1 ถ้าค่า temp มากกว่า 20 และ is_raining เป็น False จะแสดงข้อความ "Perfect day for a picnic!"<br>
# 2.2 ถ้า temp มากกว่าหรือเท่ากับ 20 หรือ is_raining เป็น True<br> จะแสดงข้อความ "Stay indoors or bring an umbrella."<br>
# 2.3 ถ้าไม่ตรงกับเงื่อนไขในข้อ 2.1, 2.2 จะแสดงข้อความ "Unsure about the weather."
#
# บล็อค B
# 1. กำหนด string "Python 2026 Engine" ใส่ใน phrase
# 2. ใช้การ comprehension โดยมีลำดับการทำงานดังนี้<br>
# 2.1 แปลงตัวอัษรทั้งหมดให้เป็นตัวพิมพ์เล็ก<br>
# 2.2 ใช้ for เพื่อเข้าถึงแต่ละตัวอักษรใน phrase<br>
# 2.3 ตรวจสอบว่าตัวอักษรแต่ละตัวเป็นพยัญชนะและไม่ใช่ a e i o u ใช่หรือไม่ หากเป็นจริงตัวอักษรนั้นจะถูกเพิ่มใน consonants แต่ถ้ามีข้อใดข้อหนึ่งเป็นเท็จจะถูกคัดออก
# 3. แสดงตัวอักษรทั้งหมดที่ผ่านเงื่อนไข

# %% [markdown]
# ### Activity 2.2

# %%
import time

print("Game Start!!!")
text = "คุณเป็นคุกกี้ คุณตื่นขึ้นมาและพบว่าอยู่ในบ้านของแม่มดใจร้าย คุณตกใจมากและพยายามหาทางหนี คุณคิดว่าวิธีไหนที่จะหนีได้ดีที่สุด"

for char in text:
    print(char, end='', flush=True)
    time.sleep(0.02)

print()

option = ""
while option not in ['a', 'b', 'c']:
  print("a. หน้าต่าง")
  print("b. ท่อระบายน้ำ")
  print("c. ประตู")
  option = input("พิมพ์ตัวเลือกของคุณ (a, b, c): ")

  if option not in ['a', 'b', 'c']:
    print()
    print(f"{option} ไม่ใช่ตัวเลือกที่ถูกต้อง กรุณาเลือก a, b หรือ c เท่านั้น")

if option == 'b':
  text = "Game Over...."
  for char in text:
      print(char, end='', flush=True)
      time.sleep(0.2)
  print()
  print()
  print("คุณเป็นคุกกี้ คุณจะค่อยๆ ละลลายและตายในท่อระบายน้ำอย่างน่าสยดสยอง")
else:
  print()
  text = "ตัดสินใจได้ดีมาก! เอาล่ะ ปฏิบัติการหลบหนีเริ่มได้!"
  for char in text:
      print(char, end='', flush=True)
      time.sleep(0.05)
  print()
  text = "เพล๊ง! แย่ล่ะ ดันเผลอทำขวดแก้วล้มซะได้... อ๊ะ! แม่มดกำลังมาทางนี้!!!! ต้องหาที่หลบด่วน!"
  for char in text:
      print(char, end='', flush=True)
      time.sleep(0.1)
  print()

  option2 = ''
  while option2 not in ['a', 'b', 'c']:
    print("a. หลบหลังผ้าม่าน")
    print("b. หลบในลิ้นชัก")
    print("c. ไม่หลบ แต่เผชิญหน้ากับแม่มด")
    option2 = input("พิมพ์ตัวเลือกของคุณ (a, b, c): ")

    if option2 not in ['a', 'b', 'c']:
      print()
      print(f"{option} ไม่ใช่ตัวเลือกที่ถูกต้อง กรุณาเลือก a, b หรือ c เท่านั้น")

  if option2 == 'c':
    text = "Game Over...."
    for char in text:
      print(char, end='', flush=True)
      time.sleep(0.2)
    print()
    print("แม่มดเห็นคุณ และจับคุณกินเป็นอาหารเช้า...")
  else:
    print()
    text = "ฟิ้ว... แม่มดเดินผ่านไปแล้ว โล่งอกไปที ลาก่อนนางแม่มดเฒ่า..."
    for char in text:
      print(char, end='', flush=True)
      time.sleep(0.05)
    print()
    print()
    print("Game Ended")
    print("Thank you for your attention.")
